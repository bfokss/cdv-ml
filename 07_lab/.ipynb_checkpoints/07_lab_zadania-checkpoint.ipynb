# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from IPython.display import display, HTML
import string
# %matplotlib notebook

# %% [markdown]
# 1. Web scraping
#
#     ○ Korzystając z metody pd.read_html(‘http.someurl.com’) pobierz listę dostępnych
#     podstron ze strony http://cdv.brightcode.pl/wolneodpracy
#
#     ○ Następnie iterując po pobranych linkach pobierz zawartość tabel z podstron. Dane zgromadź w
#     4 obiektach DataFrame odpowiadających dniom wolnym w 2018, 2019 oraz długim
#     weekendom 2018, 2019. Zastosuj się do reguł zawartych w robots.txt.

# %%
subpages = pd.read_html('http://cdv.brightcode.pl/wolneodpracy')
subpages
# Out:
# [    rok                                             URL  link
#  0  2018  http://cdv.brightcode.pl/wolneodpracy/2018.php  2018
#  1  2019  http://cdv.brightcode.pl/wolneodpracy/2019.php  2019]

# %%
free2018 = pd.read_html(subpages[0].URL[0])
free2019 = pd.read_html(subpages[0].URL[1])
wknd2018 = free2018[1]
wknd2019 = free2019[1]

# %%
display(wknd2018)
display(wknd2019)
# Out:
#    Ile dni?                     Data                     Które święta zawiera
# 0         3  30 grudnia - 1 stycznia      Nowy Rok, Świętej Bożej Rodzicielki
# 1         3    31 marca - 2 kwietnia      Wielkanoc, Poniedziałek Wielkanocny
# 2         4     28 kwietnia - 1 maja                             Święto Pracy
# 3         4               3 - 6 maja                Święto Konstytucji 3 Maja
# 4         4      31 maja - 3 czerwca                               Boże Ciało
# 5         4          1 - 4 listopada                      Wszystkich Świętych
# 6         5          22 - 26 grudnia  pierwszy dzień świąt, drugi dzień świąt
#    Ile dni?                     Data  \
# 0         4  29 grudnia - 1 stycznia
# 1         3         20 - 22 kwietnia
# 2         5               1 - 5 maja
# 3         4          20 - 23 czerwca
# 4         4         15 - 18 sierpnia
# 5         3          1 - 3 listopada
# 6         3         9 - 11 listopada
# 7         5          25 - 29 grudnia
#
#                                 Które święta zawiera
# 0                Nowy Rok, Świętej Bożej Rodzicielki
# 1                Wielkanoc, Poniedziałek Wielkanocny
# 2            Święto Pracy, Święto Konstytucji 3 Maja
# 3                                         Boże Ciało
# 4  Święto Wojska Polskiego, Wniebowzięcie Najświę...
# 5                                Wszystkich Świętych
# 6                              Święto Niepodległości
# 7  Boże Narodzenie (pierwszy dzień), Boże Narodze...

# %%
free2018 = free2018[0]
free2019 = free2019[0]

# %%
display(free2018)
display(free2019)
# Out:
#            Data         Dzień                                  Święta
# 0     1 styczeń  poniedziałek                                Nowy Rok
# 1     6 styczeń        sobota                     Święto Trzech Króli
# 2    1 kwiecień     niedziela                               Wielkanoc
# 3    2 kwiecień  poniedziałek                Poniedziałek Wielkanocny
# 4         1 maj        wtorek                            Święto Pracy
# 5         3 maj      czwartek               Święto Konstytucji 3 Maja
# 6        20 maj     niedziela                         Zielone Świątki
# 7        31 maj      czwartek                              Boże Ciało
# 8   15 sierpień         środa  Wniebowzięcie Najświętszej Maryi Panny
# 9    1 listopad      czwartek                     Wszystkich Świętych
# 10  11 listopad     niedziela                   Święto Niepodległości
# 11  25 grudzień        wtorek        Pierwszy dzień Bożego Narodzenia
# 12  26 grudzień         środa           Drugi dzień Bożego Narodzenia
#            Data         Dzień                                  Święta
# 0     1 styczeń        wtorek                                Nowy Rok
# 1     6 styczeń     niedziela                     Święto Trzech Króli
# 2   21 kwiecień     niedziela                               Wielkanoc
# 3   22 kwiecień  poniedziałek                Poniedziałek Wielkanocny
# 4         1 maj         środa                            Święto Pracy
# 5         3 maj        piątek               Święto Konstytucji 3 Maja
# 6    9 czerwiec     niedziela                         Zielone Świątki
# 7   20 czerwiec      czwartek                              Boże Ciało
# 8   15 sierpień      czwartek  Wniebowzięcie Najświętszej Maryi Panny
# 9    1 listopad        piątek                     Wszystkich Świętych
# 10  11 listopad  poniedziałek                   Święto Niepodległości
# 11  25 grudzień         środa        Pierwszy dzień Bożego Narodzenia
# 12  26 grudzień      czwartek           Drugi dzień Bożego Narodzenia

# %% [markdown]
# 2. Eksport do csv
#
#     ○ Utwórz 2 nowe obiekty DataFrame w których zgromadzisz odpowiednio dane dotyczące dni
#     wolnych oraz dane dotyczące długich weekendów. W każdej ramce danych uwzględnij
#     dodatkowo kolumnę year i uzupełnij odpowiednia wartością.
#
#     ○ Zapisz obiekty DataFrame w plikach .csv.

# %%
free2018 = free2018.rename(columns = {'Święta': 'holidays', 'Data': 'date', 'Dzień': 'which_day'})
wknd2018 = wknd2018.rename(columns = {'Ile dni?': 'how_many_days', 'Data': 'date', 'Które święta zawiera': 'holidays'})

free2019 = free2019.rename(columns = {'Święta': 'holidays', 'Data': 'date', 'Dzień': 'which_day'})
wknd2019 = wknd2019.rename(columns = {'Ile dni?': 'how_many_days', 'Data': 'date', 'Które święta zawiera': 'holidays'})

free2019['year'] = 2019
wknd2019['year'] = 2019

free2018['year'] = 2018
wknd2018['year'] = 2018

free = free2018.append(free2019)
wknd = wknd2018.append(wknd2019)


display(free)
display(wknd)
# Out:
#            date     which_day                                holidays  year
# 0     1 styczeń  poniedziałek                                Nowy Rok  2018
# 1     6 styczeń        sobota                     Święto Trzech Króli  2018
# 2    1 kwiecień     niedziela                               Wielkanoc  2018
# 3    2 kwiecień  poniedziałek                Poniedziałek Wielkanocny  2018
# 4         1 maj        wtorek                            Święto Pracy  2018
# 5         3 maj      czwartek               Święto Konstytucji 3 Maja  2018
# 6        20 maj     niedziela                         Zielone Świątki  2018
# 7        31 maj      czwartek                              Boże Ciało  2018
# 8   15 sierpień         środa  Wniebowzięcie Najświętszej Maryi Panny  2018
# 9    1 listopad      czwartek                     Wszystkich Świętych  2018
# 10  11 listopad     niedziela                   Święto Niepodległości  2018
# 11  25 grudzień        wtorek        Pierwszy dzień Bożego Narodzenia  2018
# 12  26 grudzień         środa           Drugi dzień Bożego Narodzenia  2018
# 0     1 styczeń        wtorek                                Nowy Rok  2019
# 1     6 styczeń     niedziela                     Święto Trzech Króli  2019
# 2   21 kwiecień     niedziela                               Wielkanoc  2019
# 3   22 kwiecień  poniedziałek                Poniedziałek Wielkanocny  2019
# 4         1 maj         środa                            Święto Pracy  2019
# 5         3 maj        piątek               Święto Konstytucji 3 Maja  2019
# 6    9 czerwiec     niedziela                         Zielone Świątki  2019
# 7   20 czerwiec      czwartek                              Boże Ciało  2019
# 8   15 sierpień      czwartek  Wniebowzięcie Najświętszej Maryi Panny  2019
# 9    1 listopad        piątek                     Wszystkich Świętych  2019
# 10  11 listopad  poniedziałek                   Święto Niepodległości  2019
# 11  25 grudzień         środa        Pierwszy dzień Bożego Narodzenia  2019
# 12  26 grudzień      czwartek           Drugi dzień Bożego Narodzenia  2019
#    how_many_days                     date  \
# 0              3  30 grudnia - 1 stycznia
# 1              3    31 marca - 2 kwietnia
# 2              4     28 kwietnia - 1 maja
# 3              4               3 - 6 maja
# 4              4      31 maja - 3 czerwca
# 5              4          1 - 4 listopada
# 6              5          22 - 26 grudnia
# 0              4  29 grudnia - 1 stycznia
# 1              3         20 - 22 kwietnia
# 2              5               1 - 5 maja
# 3              4          20 - 23 czerwca
# 4              4         15 - 18 sierpnia
# 5              3          1 - 3 listopada
# 6              3         9 - 11 listopada
# 7              5          25 - 29 grudnia
#
#                                             holidays  year
# 0                Nowy Rok, Świętej Bożej Rodzicielki  2018
# 1                Wielkanoc, Poniedziałek Wielkanocny  2018
# 2                                       Święto Pracy  2018
# 3                          Święto Konstytucji 3 Maja  2018
# 4                                         Boże Ciało  2018
# 5                                Wszystkich Świętych  2018
# 6            pierwszy dzień świąt, drugi dzień świąt  2018
# 0                Nowy Rok, Świętej Bożej Rodzicielki  2019
# 1                Wielkanoc, Poniedziałek Wielkanocny  2019
# 2            Święto Pracy, Święto Konstytucji 3 Maja  2019
# 3                                         Boże Ciało  2019
# 4  Święto Wojska Polskiego, Wniebowzięcie Najświę...  2019
# 5                                Wszystkich Świętych  2019
# 6                              Święto Niepodległości  2019
# 7  Boże Narodzenie (pierwszy dzień), Boże Narodze...  2019

# %%
wknd.to_csv('wknd.csv')
free.to_csv('free.csv')

# %% [markdown]
# 3. Import i przetwarzanie
#
#     ○ Zaimportuj dane zapisane w poprzednim zadaniu.
#
#     ○ W ramce danych z dniami wolnymi dodaj kolumny: day oraz month
#
#     ○ Wypełnij dane w nowo dodanych kolumnach na podstawie zawartości kolumny z datą.
#
#     ○ W ramce danych z długimi weekendami dodaj kolumnę month i wypełnij na podstawie
#     kolumny z datą.

# %%
i_free = pd.read_csv('free.csv')
display(i_free)
# Out:
#     Unnamed: 0         date     which_day  \
# 0            0    1 styczeń  poniedziałek
# 1            1    6 styczeń        sobota
# 2            2   1 kwiecień     niedziela
# 3            3   2 kwiecień  poniedziałek
# 4            4        1 maj        wtorek
# 5            5        3 maj      czwartek
# 6            6       20 maj     niedziela
# 7            7       31 maj      czwartek
# 8            8  15 sierpień         środa
# 9            9   1 listopad      czwartek
# 10          10  11 listopad     niedziela
# 11          11  25 grudzień        wtorek
# 12          12  26 grudzień         środa
# 13           0    1 styczeń        wtorek
# 14           1    6 styczeń     niedziela
# 15           2  21 kwiecień     niedziela
# 16           3  22 kwiecień  poniedziałek
# 17           4        1 maj         środa
# 18           5        3 maj        piątek
# 19           6   9 czerwiec     niedziela
# 20           7  20 czerwiec      czwartek
# 21           8  15 sierpień      czwartek
# 22           9   1 listopad        piątek
# 23          10  11 listopad  poniedziałek
# 24          11  25 grudzień         środa
# 25          12  26 grudzień      czwartek
#
#                                   holidays  year
# 0                                 Nowy Rok  2018
# 1                      Święto Trzech Króli  2018
# 2                                Wielkanoc  2018
# 3                 Poniedziałek Wielkanocny  2018
# 4                             Święto Pracy  2018
# 5                Święto Konstytucji 3 Maja  2018
# 6                          Zielone Świątki  2018
# 7                               Boże Ciało  2018
# 8   Wniebowzięcie Najświętszej Maryi Panny  2018
# 9                      Wszystkich Świętych  2018
# 10                   Święto Niepodległości  2018
# 11        Pierwszy dzień Bożego Narodzenia  2018
# 12           Drugi dzień Bożego Narodzenia  2018
# 13                                Nowy Rok  2019
# 14                     Święto Trzech Króli  2019
# 15                               Wielkanoc  2019
# 16                Poniedziałek Wielkanocny  2019
# 17                            Święto Pracy  2019
# 18               Święto Konstytucji 3 Maja  2019
# 19                         Zielone Świątki  2019
# 20                              Boże Ciało  2019
# 21  Wniebowzięcie Najświętszej Maryi Panny  2019
# 22                     Wszystkich Świętych  2019
# 23                   Święto Niepodległości  2019
# 24        Pierwszy dzień Bożego Narodzenia  2019
# 25           Drugi dzień Bożego Narodzenia  2019

# %%
i_wknd = pd.read_csv('wknd.csv')
display(i_wknd)
# Out:
#     Unnamed: 0  how_many_days                     date  \
# 0            0              3  30 grudnia - 1 stycznia
# 1            1              3    31 marca - 2 kwietnia
# 2            2              4     28 kwietnia - 1 maja
# 3            3              4               3 - 6 maja
# 4            4              4      31 maja - 3 czerwca
# 5            5              4          1 - 4 listopada
# 6            6              5          22 - 26 grudnia
# 7            0              4  29 grudnia - 1 stycznia
# 8            1              3         20 - 22 kwietnia
# 9            2              5               1 - 5 maja
# 10           3              4          20 - 23 czerwca
# 11           4              4         15 - 18 sierpnia
# 12           5              3          1 - 3 listopada
# 13           6              3         9 - 11 listopada
# 14           7              5          25 - 29 grudnia
#
#                                              holidays  year
# 0                 Nowy Rok, Świętej Bożej Rodzicielki  2018
# 1                 Wielkanoc, Poniedziałek Wielkanocny  2018
# 2                                        Święto Pracy  2018
# 3                           Święto Konstytucji 3 Maja  2018
# 4                                          Boże Ciało  2018
# 5                                 Wszystkich Świętych  2018
# 6             pierwszy dzień świąt, drugi dzień świąt  2018
# 7                 Nowy Rok, Świętej Bożej Rodzicielki  2019
# 8                 Wielkanoc, Poniedziałek Wielkanocny  2019
# 9             Święto Pracy, Święto Konstytucji 3 Maja  2019
# 10                                         Boże Ciało  2019
# 11  Święto Wojska Polskiego, Wniebowzięcie Najświę...  2019
# 12                                Wszystkich Świętych  2019
# 13                              Święto Niepodległości  2019
# 14  Boże Narodzenie (pierwszy dzień), Boże Narodze...  2019

# %%
i_free['day'] = i_free['date'].str.extract('(\d+)')
i_free['month'] = i_free['date'].str.findall(r'([aąbcćdeęfghijklłmnńoópqrsśtuvwxyzźż])')
i_free['month'] = i_free['month'].str.join('')

# %%
display(i_free)
# Out:
#     Unnamed: 0         date     which_day  \
# 0            0    1 styczeń  poniedziałek
# 1            1    6 styczeń        sobota
# 2            2   1 kwiecień     niedziela
# 3            3   2 kwiecień  poniedziałek
# 4            4        1 maj        wtorek
# 5            5        3 maj      czwartek
# 6            6       20 maj     niedziela
# 7            7       31 maj      czwartek
# 8            8  15 sierpień         środa
# 9            9   1 listopad      czwartek
# 10          10  11 listopad     niedziela
# 11          11  25 grudzień        wtorek
# 12          12  26 grudzień         środa
# 13           0    1 styczeń        wtorek
# 14           1    6 styczeń     niedziela
# 15           2  21 kwiecień     niedziela
# 16           3  22 kwiecień  poniedziałek
# 17           4        1 maj         środa
# 18           5        3 maj        piątek
# 19           6   9 czerwiec     niedziela
# 20           7  20 czerwiec      czwartek
# 21           8  15 sierpień      czwartek
# 22           9   1 listopad        piątek
# 23          10  11 listopad  poniedziałek
# 24          11  25 grudzień         środa
# 25          12  26 grudzień      czwartek
#
#                                   holidays  year day     month
# 0                                 Nowy Rok  2018   1   styczeń
# 1                      Święto Trzech Króli  2018   6   styczeń
# 2                                Wielkanoc  2018   1  kwiecień
# 3                 Poniedziałek Wielkanocny  2018   2  kwiecień
# 4                             Święto Pracy  2018   1       maj
# 5                Święto Konstytucji 3 Maja  2018   3       maj
# 6                          Zielone Świątki  2018  20       maj
# 7                               Boże Ciało  2018  31       maj
# 8   Wniebowzięcie Najświętszej Maryi Panny  2018  15  sierpień
# 9                      Wszystkich Świętych  2018   1  listopad
# 10                   Święto Niepodległości  2018  11  listopad
# 11        Pierwszy dzień Bożego Narodzenia  2018  25  grudzień
# 12           Drugi dzień Bożego Narodzenia  2018  26  grudzień
# 13                                Nowy Rok  2019   1   styczeń
# 14                     Święto Trzech Króli  2019   6   styczeń
# 15                               Wielkanoc  2019  21  kwiecień
# 16                Poniedziałek Wielkanocny  2019  22  kwiecień
# 17                            Święto Pracy  2019   1       maj
# 18               Święto Konstytucji 3 Maja  2019   3       maj
# 19                         Zielone Świątki  2019   9  czerwiec
# 20                              Boże Ciało  2019  20  czerwiec
# 21  Wniebowzięcie Najświętszej Maryi Panny  2019  15  sierpień
# 22                     Wszystkich Świętych  2019   1  listopad
# 23                   Święto Niepodległości  2019  11  listopad
# 24        Pierwszy dzień Bożego Narodzenia  2019  25  grudzień
# 25           Drugi dzień Bożego Narodzenia  2019  26  grudzień

# %%
display(i_wknd)
# Out:
#     Unnamed: 0  how_many_days                     date  \
# 0            0              3  30 grudnia - 1 stycznia
# 1            1              3    31 marca - 2 kwietnia
# 2            2              4     28 kwietnia - 1 maja
# 3            3              4               3 - 6 maja
# 4            4              4      31 maja - 3 czerwca
# 5            5              4          1 - 4 listopada
# 6            6              5          22 - 26 grudnia
# 7            0              4  29 grudnia - 1 stycznia
# 8            1              3         20 - 22 kwietnia
# 9            2              5               1 - 5 maja
# 10           3              4          20 - 23 czerwca
# 11           4              4         15 - 18 sierpnia
# 12           5              3          1 - 3 listopada
# 13           6              3         9 - 11 listopada
# 14           7              5          25 - 29 grudnia
#
#                                              holidays  year
# 0                 Nowy Rok, Świętej Bożej Rodzicielki  2018
# 1                 Wielkanoc, Poniedziałek Wielkanocny  2018
# 2                                        Święto Pracy  2018
# 3                           Święto Konstytucji 3 Maja  2018
# 4                                          Boże Ciało  2018
# 5                                 Wszystkich Świętych  2018
# 6             pierwszy dzień świąt, drugi dzień świąt  2018
# 7                 Nowy Rok, Świętej Bożej Rodzicielki  2019
# 8                 Wielkanoc, Poniedziałek Wielkanocny  2019
# 9             Święto Pracy, Święto Konstytucji 3 Maja  2019
# 10                                         Boże Ciało  2019
# 11  Święto Wojska Polskiego, Wniebowzięcie Najświę...  2019
# 12                                Wszystkich Świętych  2019
# 13                              Święto Niepodległości  2019
# 14  Boże Narodzenie (pierwszy dzień), Boże Narodze...  2019

# %%
i_wknd['month'] = i_wknd['date'].str.findall(r'([ aąbcćdeęfghijklłmnńoópqrsśtuvwxyzźż])')
i_wknd['month'] = i_wknd['month'].str.join('')

# %%
display(i_wknd)
# Out:
#     Unnamed: 0  how_many_days                     date  \
# 0            0              3  30 grudnia - 1 stycznia
# 1            1              3    31 marca - 2 kwietnia
# 2            2              4     28 kwietnia - 1 maja
# 3            3              4               3 - 6 maja
# 4            4              4      31 maja - 3 czerwca
# 5            5              4          1 - 4 listopada
# 6            6              5          22 - 26 grudnia
# 7            0              4  29 grudnia - 1 stycznia
# 8            1              3         20 - 22 kwietnia
# 9            2              5               1 - 5 maja
# 10           3              4          20 - 23 czerwca
# 11           4              4         15 - 18 sierpnia
# 12           5              3          1 - 3 listopada
# 13           6              3         9 - 11 listopada
# 14           7              5          25 - 29 grudnia
#
#                                              holidays  year  \
# 0                 Nowy Rok, Świętej Bożej Rodzicielki  2018
# 1                 Wielkanoc, Poniedziałek Wielkanocny  2018
# 2                                        Święto Pracy  2018
# 3                           Święto Konstytucji 3 Maja  2018
# 4                                          Boże Ciało  2018
# 5                                 Wszystkich Świętych  2018
# 6             pierwszy dzień świąt, drugi dzień świąt  2018
# 7                 Nowy Rok, Świętej Bożej Rodzicielki  2019
# 8                 Wielkanoc, Poniedziałek Wielkanocny  2019
# 9             Święto Pracy, Święto Konstytucji 3 Maja  2019
# 10                                         Boże Ciało  2019
# 11  Święto Wojska Polskiego, Wniebowzięcie Najświę...  2019
# 12                                Wszystkich Świętych  2019
# 13                              Święto Niepodległości  2019
# 14  Boże Narodzenie (pierwszy dzień), Boże Narodze...  2019
#
#                   month
# 0    grudnia   stycznia
# 1      marca   kwietnia
# 2       kwietnia   maja
# 3                  maja
# 4        maja   czerwca
# 5             listopada
# 6               grudnia
# 7    grudnia   stycznia
# 8              kwietnia
# 9                  maja
# 10              czerwca
# 11             sierpnia
# 12            listopada
# 13            listopada
# 14              grudnia

# %% [markdown]
# 4. Wizualizacja danych Pandas
#
#     ○ Za pomocą wykresu słupkowego przedstaw porównanie dni wolnych w każdym miesiącu 2018
#     w zestawieniu z 2019.
#
#     ○ Utwórz obszar wykresu wielkości 2x2. Następnie na wykresach kołowych zwizualizuj dla
#     danego roku procentowy udział sumy dni wchodzących w skład długich weekendów w każdym
#     miesiącu oraz każdym kwartale.

# %%
months = i_free['month']
values = pd.value_counts(months)
values = pd.DataFrame(values)
months = values.index
values = values.reset_index(drop=True)

# %%
months
# Out:
# Index(['maj', 'styczeń', 'kwiecień', 'listopad', 'grudzień', 'sierpień',
#        'czerwiec'],
#       dtype='object')

# %%
values = pd.Series(values.month)

# %%
m_month = plt.bar(months,values)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pie1 = fig.add_subplot(221)
pie2 = fig.add_subplot(222)
pie3 = fig.add_subplot(223)
pie4 = fig.add_subplot(224)

# %%
quarter1 = ['Stycznia', 'Lutego', 'Marca']
quarter2 = ['Kwietnia', 'Maja', 'Czerwca', ]
quarter3 = ['Lipca','Sierpnia', 'Września']
quarter4 = ['Października', 'Listopada', 'Grudnia']

# %%
data = [i_wknd['month'], i_wknd['how_many_days'], i_wknd['year']]
headers = ["month", "how_many_days", "year"]
months_values = pd.concat(data, axis=1, keys=headers)

# %%
months_values
# Out:
#                   month  how_many_days
# 0    grudnia   stycznia              3
# 1      marca   kwietnia              3
# 2       kwietnia   maja              4
# 3                  maja              4
# 4        maja   czerwca              4
# 5             listopada              4
# 6               grudnia              5
# 7    grudnia   stycznia              4
# 8              kwietnia              3
# 9                  maja              5
# 10              czerwca              4
# 11             sierpnia              4
# 12            listopada              3
# 13            listopada              3
# 14              grudnia              5

# %%
wig = pd.read_html('https://notowania.pb.pl/instrument/PL9999999987/wig20')

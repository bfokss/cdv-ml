# %% [markdown]
# # TEXT PROCESSING

# %% [markdown]
# SENTIMENT ANALYSIS EXAMPLE (CLASSIFYING TEXT)

# %%
import pandas as pd # Pandas - Series, DataFrame - ramki danych

train = pd.read_csv('train_E6oV3lV.csv')

# %%
train.head(100)
# Out:
#      id  label                                              tweet
# 0     1      0   @user when a father is dysfunctional and is s...
# 1     2      0  @user @user thanks for #lyft credit i can't us...
# 2     3      0                                bihday your majesty
# 3     4      0  #model   i love u take with u all the time in ...
# 4     5      0             factsguide: society now    #motivation
# 5     6      0  [2/2] huge fan fare and big talking before the...
# 6     7      0   @user camping tomorrow @user @user @user @use...
# 7     8      0  the next school year is the year for exams.ð...
# 8     9      0  we won!!! love the land!!! #allin #cavs #champ...
# 9    10      0   @user @user welcome here !  i'm   it's so #gr...
# 10   11      0   â #ireland consumer price index (mom) climb...
# 11   12      0  we are so selfish. #orlando #standwithorlando ...
# 12   13      0  i get to see my daddy today!!   #80days #getti...
# 13   14      1  @user #cnn calls #michigan middle school 'buil...
# 14   15      1  no comment!  in #australia   #opkillingbay #se...
# 15   16      0  ouch...junior is angryð#got7 #junior #yugyo...
# 16   17      0  i am thankful for having a paner. #thankful #p...
# 17   18      1                             retweet if you agree!
# 18   19      0  its #friday! ð smiles all around via ig use...
# 19   20      0  as we all know, essential oils are not made of...
# 20   21      0  #euro2016 people blaming ha for conceded goal ...
# 21   22      0  sad little dude..   #badday #coneofshame #cats...
# 22   23      0  product of the day: happy man #wine tool  who'...
# 23   24      1    @user @user lumpy says i am a . prove it lumpy.
# 24   25      0   @user #tgif   #ff to my #gamedev #indiedev #i...
# 25   26      0  beautiful sign by vendor 80 for $45.00!! #upsi...
# 26   27      0   @user all #smiles when #media is   !! ðð...
# 27   28      0  we had a great panel on the mediatization of t...
# 28   29      0        happy father's day @user ðððð
# 29   30      0  50 people went to nightclub to have a good nig...
# ..  ...    ...                                                ...
# 70   71      0   @user # if you #luv #hottweets like this from...
# 71   72      0  our new brochures have arrived! how exciting!!...
# 72   73      0  so much stuff happening in florida! first #orl...
# 73   74      0  @user ferrari will do itðªð¼ for the sake ...
# 74   75      0                      aced my first test!   #proud
# 75   76      0    seeks probe into #udtapunjab' leak, points f...
# 76   77      0  @user wrapping up #senseaboutmaths @user 6th  ...
# 77   78      1  @user hey, white people: you can call people '...
# 78   79      0  @user @user you might be. just have not shown ...
# 79   80      0  sometimes you have to raise a few brows to rai...
# 80   81      0    about that ððð #greathonour #career...
# 81   82      0   @user designing #innovative learning space @u...
# 82   83      1  how the #altright uses  &amp; insecurity to lu...
# 83   84      0  carrying a gun wouldn't of helped if you can't...
# 84   85      0  use the power of your mind to #heal your body!...
# 85   86      0               woohoo!! just over 5 weeks to go!
# 86   87      0  being in a far away place where you have no fa...
# 87   88      0  ready to rehearse tonight with new music and n...
# 88   89      0  now on monday nights at 8pm on #up channel!!!!...
# 89   90      0      watching the new episodes of @user on @user
# 90   91      0   @user offline now after a very nice and long ...
# 91   92      0                 15 things incredibly   #people do
# 92   93      0  yes! received my acceptance letter for my mast...
# 93   94      0  daughter riding her bike around driveway, son ...
# 94   95      0  omg!!! loving this station!!! way to jam out a...
# 95   96      0  @user i'll always hope that one day i'll get t...
# 96   97      0  #model   i love u take with u all the time in ...
# 97   98      0       couple having sex fat naked japanese girls
# 98   99      0  #hump on that    #hump day #humpersð© @ edwa...
# 99  100      0  personalised we... gbp 7.99 get here:  #shop #...
#
# [100 rows x 3 columns]

# %%
train['word_count'] = train['tweet'].apply(lambda x: len(str(x).split(" ")))
train[['tweet','word_count']].head()
# Out:
#                                                tweet  word_count
# 0   @user when a father is dysfunctional and is s...          21
# 1  @user @user thanks for #lyft credit i can't us...          22
# 2                                bihday your majesty           5
# 3  #model   i love u take with u all the time in ...          17
# 4             factsguide: society now    #motivation           8

# %%
train['char_count'] = train['tweet'].str.len() ## this also includes spaces
train[['tweet','char_count']].head()
# Out:
#                                                tweet  char_count
# 0   @user when a father is dysfunctional and is s...         102
# 1  @user @user thanks for #lyft credit i can't us...         122
# 2                                bihday your majesty          21
# 3  #model   i love u take with u all the time in ...          86
# 4             factsguide: society now    #motivation          39

# %%
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

train['avg_word'] = train['tweet'].apply(lambda x: avg_word(x))
train[['tweet','avg_word']].head()
# Out:
#                                                tweet  avg_word
# 0   @user when a father is dysfunctional and is s...  4.555556
# 1  @user @user thanks for #lyft credit i can't us...  5.315789
# 2                                bihday your majesty  5.666667
# 3  #model   i love u take with u all the time in ...  4.928571
# 4             factsguide: society now    #motivation  8.000000

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop = stopwords.words('english')

train['stopwords'] = train['tweet'].apply(lambda x: len([x for x in x.split() if x in stop]))
train[['tweet','stopwords']].head()
# Out:
# [nltk_data] Downloading package stopwords to /home/michal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                tweet  stopwords
# 0   @user when a father is dysfunctional and is s...         10
# 1  @user @user thanks for #lyft credit i can't us...          5
# 2                                bihday your majesty          1
# 3  #model   i love u take with u all the time in ...          5
# 4             factsguide: society now    #motivation          1

# %%
 stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
train['hastags'] = train['tweet'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
train[['tweet','hastags']].head()
# Out:
#                                                tweet  hastags
# 0   @user when a father is dysfunctional and is s...        1
# 1  @user @user thanks for #lyft credit i can't us...        3
# 2                                bihday your majesty        0
# 3  #model   i love u take with u all the time in ...        1
# 4             factsguide: society now    #motivation        1

# %%
train['numerics'] = train['tweet'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
train[['tweet','numerics']].head(100)
# Out:
#                                                 tweet  numerics
# 0    @user when a father is dysfunctional and is s...         0
# 1   @user @user thanks for #lyft credit i can't us...         0
# 2                                 bihday your majesty         0
# 3   #model   i love u take with u all the time in ...         0
# 4              factsguide: society now    #motivation         0
# 5   [2/2] huge fan fare and big talking before the...         0
# 6    @user camping tomorrow @user @user @user @use...         0
# 7   the next school year is the year for exams.ð...         0
# 8   we won!!! love the land!!! #allin #cavs #champ...         0
# 9    @user @user welcome here !  i'm   it's so #gr...         0
# 10   â #ireland consumer price index (mom) climb...         0
# 11  we are so selfish. #orlando #standwithorlando ...         0
# 12  i get to see my daddy today!!   #80days #getti...         0
# 13  @user #cnn calls #michigan middle school 'buil...         0
# 14  no comment!  in #australia   #opkillingbay #se...         0
# 15  ouch...junior is angryð#got7 #junior #yugyo...         0
# 16  i am thankful for having a paner. #thankful #p...         0
# 17                             retweet if you agree!          0
# 18  its #friday! ð smiles all around via ig use...         0
# 19  as we all know, essential oils are not made of...         0
# 20  #euro2016 people blaming ha for conceded goal ...         0
# 21  sad little dude..   #badday #coneofshame #cats...         0
# 22  product of the day: happy man #wine tool  who'...         0
# 23    @user @user lumpy says i am a . prove it lumpy.         0
# 24   @user #tgif   #ff to my #gamedev #indiedev #i...         0
# 25  beautiful sign by vendor 80 for $45.00!! #upsi...         1
# 26   @user all #smiles when #media is   !! ðð...         0
# 27  we had a great panel on the mediatization of t...         0
# 28        happy father's day @user ðððð           0
# 29  50 people went to nightclub to have a good nig...         2
# ..                                                ...       ...
# 70   @user # if you #luv #hottweets like this from...         0
# 71  our new brochures have arrived! how exciting!!...         0
# 72  so much stuff happening in florida! first #orl...         0
# 73  @user ferrari will do itðªð¼ for the sake ...         0
# 74                      aced my first test!   #proud          0
# 75    seeks probe into #udtapunjab' leak, points f...         0
# 76  @user wrapping up #senseaboutmaths @user 6th  ...         0
# 77  @user hey, white people: you can call people '...         0
# 78  @user @user you might be. just have not shown ...         0
# 79  sometimes you have to raise a few brows to rai...         0
# 80    about that ððð #greathonour #career...         0
# 81   @user designing #innovative learning space @u...         0
# 82  how the #altright uses  &amp; insecurity to lu...         0
# 83  carrying a gun wouldn't of helped if you can't...         0
# 84  use the power of your mind to #heal your body!...         0
# 85               woohoo!! just over 5 weeks to go!            1
# 86  being in a far away place where you have no fa...         0
# 87  ready to rehearse tonight with new music and n...         0
# 88  now on monday nights at 8pm on #up channel!!!!...         0
# 89      watching the new episodes of @user on @user           0
# 90   @user offline now after a very nice and long ...         0
# 91                 15 things incredibly   #people do          1
# 92  yes! received my acceptance letter for my mast...         0
# 93  daughter riding her bike around driveway, son ...         0
# 94  omg!!! loving this station!!! way to jam out a...         0
# 95  @user i'll always hope that one day i'll get t...         0
# 96  #model   i love u take with u all the time in ...         0
# 97       couple having sex fat naked japanese girls           0
# 98  #hump on that    #hump day #humpersð© @ edwa...         0
# 99  personalised we... gbp 7.99 get here:  #shop #...         0
#
# [100 rows x 2 columns]

# %%
train['upper'] = train['tweet'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
train[['tweet','upper']].head()
# Out:
#                                                tweet  upper
# 0   @user when a father is dysfunctional and is s...      0
# 1  @user @user thanks for #lyft credit i can't us...      0
# 2                                bihday your majesty      0
# 3  #model   i love u take with u all the time in ...      0
# 4             factsguide: society now    #motivation      0

# %%
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x.lower() for x in x.split()))
train['tweet'].head()
# Out:
# 0    @user when a father is dysfunctional and is so...
# 1    @user @user thanks for #lyft credit i can't us...
# 2                                  bihday your majesty
# 3    #model i love u take with u all the time in ur...
# 4                  factsguide: society now #motivation
# Name: tweet, dtype: object

# %%
train['tweet'] = train['tweet'].str.replace('[^\w\s]','')
train['tweet'].head()
# Out:
# 0    user when a father is dysfunctional and is so ...
# 1    user user thanks for lyft credit i cant use ca...
# 2                                  bihday your majesty
# 3    model i love u take with u all the time in urð...
# 4                    factsguide society now motivation
# Name: tweet, dtype: object

# %%
stop = stopwords.words('english')
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
train['tweet'].head()
# Out:
# 0    user father dysfunctional selfish drags kids d...
# 1    user user thanks lyft credit cant use cause do...
# 2                                       bihday majesty
# 3                model love u take u time urð ðððð ððð
# 4                        factsguide society motivation
# Name: tweet, dtype: object

# %%
freq = pd.Series(' '.join(train['tweet']).split()).value_counts()
freq = freq[freq > 500]
freq
# Out:
# life         1189
# like         1073
# today        1065
# get           998
# new           983
# positive      929
# thankful      919
# father        903
# people        871
# good          843
# make          842
# one           835
# bihday        825
# cant          802
# ððð           796
# smile         773
# ðð            763
# see           762
# go            737
# dont          718
# friend        703
# want          702
# take          672
# work          638
# need          600
# weekend       599
# healthy       596
# girl          583
# family        580
# week          572
# fun           561
# way           556
# summer        536
# got           527
# friday        517
# best          511
# u             509
# great         506
# bull          506
# year          504
# beautiful     501
# dtype: int64

# %%
freq = list(freq.index)
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['tweet'].head()
# Out:
# 0    father dysfunctional selfish drags kids dysfun...
# 1    thanks lyft credit cant use cause dont offer w...
# 2                                       bihday majesty
# 3                              model take urð ðððð ððð
# 4                        factsguide society motivation
# Name: tweet, dtype: object

# %%
freq = pd.Series(' '.join(train['tweet']).split()).value_counts()
freq = freq[freq < 5]
freq

# %%
freq = list(freq.index)
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['tweet'].head()
# Out:
# 0    father dysfunctional selfish drags kids dysfun...
# 1    thanks lyft credit cant use cause dont offer w...
# 2                                       bihday majesty
# 3                              model take urð ðððð ððð
# 4                        factsguide society motivation
# Name: tweet, dtype: object

# %%
from textblob import TextBlob
train['tweet'][:5].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0    father dysfunctional selfish drags kiss dysfun...
# 1    thanks left credit can use cause dont offer wh...
# 2                                       midday majesty
# 3                               model take or ðððð ððð
# 4                        factsguide society motivation
# Name: tweet, dtype: object

# %%
nltk.download('punkt')
TextBlob(train['tweet'][1]).words
# Out:
# [nltk_data] Downloading package punkt to /home/michal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WordList(['thanks', 'lyft', 'credit', 'cant', 'use', 'cause', 'dont', 'offer', 'wheelchair', 'vans', 'pdx', 'disapointed', 'getthanked'])

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
train['tweet'][:5].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0        father dysfunct selfish drag kid dysfunct run
# 1    thank lyft credit cant use caus dont offer whe...
# 2                                       bihday majesti
# 3                              model take urð ðððð ððð
# 4                              factsguid societi motiv
# Name: tweet, dtype: object

# %%
from textblob import Word
nltk.download('wordnet')
train['tweet'] = train['tweet'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
train['tweet'].head()
# Out:
# [nltk_data] Downloading package wordnet to /home/michal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0    father dysfunctional selfish drag kid dysfunct...
# 1    thanks lyft credit cant use cause dont offer w...
# 2                                       bihday majesty
# 3                              model take urð ðððð ððð
# 4                        factsguide society motivation
# Name: tweet, dtype: object

# %%
TextBlob(train['tweet'][0]).ngrams(2)
# Out:
# [WordList(['father', 'dysfunctional']),
#  WordList(['dysfunctional', 'selfish']),
#  WordList(['selfish', 'drag']),
#  WordList(['drag', 'kid']),
#  WordList(['kid', 'dysfunction']),
#  WordList(['dysfunction', 'run'])]

# %%
tf1 = (train['tweet'][1:2]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
tf1.columns = ['words','tf']
tf1
# Out:
#           words  tf
# 0        credit   1
# 1          dont   1
# 2         cause   1
# 3         offer   1
# 4           van   1
# 5        thanks   1
# 6          lyft   1
# 7           use   1
# 8           pdx   1
# 9          cant   1
# 10   wheelchair   1
# 11  disapointed   1
# 12   getthanked   1

# %%
import numpy as np
for i,word in enumerate(tf1['words']):
  tf1.loc[i, 'idf'] = np.log(train.shape[0]/(len(train[train['tweet'].str.contains(word)])))
tf1
# Out:
#           words  tf        idf
# 0        credit   1   7.327781
# 1          dont   1   3.745585
# 2         cause   1   5.690172
# 3         offer   1   6.522155
# 4           van   1   5.236505
# 5        thanks   1   4.597751
# 6          lyft   1   8.762865
# 7           use   1   3.552287
# 8           pdx   1   8.762865
# 9          cant   1   3.538194
# 10   wheelchair   1   9.273691
# 11  disapointed   1  10.372303
# 12   getthanked   1   9.679156

# %%
tf1['tfidf'] = tf1['tf'] * tf1['idf']
tf1
# Out:
#           words  tf        idf      tfidf
# 0        credit   1   7.327781   7.327781
# 1          dont   1   3.745585   3.745585
# 2         cause   1   5.690172   5.690172
# 3         offer   1   6.522155   6.522155
# 4           van   1   5.236505   5.236505
# 5        thanks   1   4.597751   4.597751
# 6          lyft   1   8.762865   8.762865
# 7           use   1   3.552287   3.552287
# 8           pdx   1   8.762865   8.762865
# 9          cant   1   3.538194   3.538194
# 10   wheelchair   1   9.273691   9.273691
# 11  disapointed   1  10.372303  10.372303
# 12   getthanked   1   9.679156   9.679156

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word',
 stop_words= 'english',ngram_range=(1,1))
train_vect = tfidf.fit_transform(train['tweet'])

train_vect
# Out:
# <31962x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 114043 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow = CountVectorizer(max_features=1000, lowercase=True, ngram_range=(1,2),analyzer = "word")
train_bow = bow.fit_transform(train['tweet'])
train_bow
# Out:
# <31962x1000 sparse matrix of type '<class 'numpy.longlong'>'
# 	with 135434 stored elements in Compressed Sparse Row format>

# %%
bow.vocabulary_
# Out:
# {'father': 277,
#  'kid': 451,
#  'run': 710,
#  'thanks': 846,
#  'cant': 136,
#  'use': 899,
#  'cause': 144,
#  'dont': 231,
#  'bihday': 89,
#  'model': 554,
#  'take': 823,
#  'urð': 896,
#  'ðððð': 995,
#  'ððð': 994,
#  'model take': 555,
#  'take urð': 824,
#  'urð ðððð': 897,
#  'ðððð ððð': 996,
#  'motivation': 564,
#  'fan': 273,
#  'big': 88,
#  'talking': 828,
#  'leave': 475,
#  'pay': 624,
#  'get': 338,
#  'tomorrow': 866,
#  'next': 590,
#  'school': 721,
#  'year': 979,
#  'think': 852,
#  'hate': 386,
#  'girl': 342,
#  'welcome': 940,
#  'mom': 556,
#  'may': 534,
#  'blog': 98,
#  'silver': 754,
#  'gold': 351,
#  'forex': 313,
#  'blog silver': 99,
#  'silver gold': 755,
#  'gold forex': 352,
#  'orlando': 614,
#  'orlandoshooting': 615,
#  'see': 726,
#  'daddy': 197,
#  'today': 864,
#  'call': 131,
#  'comment': 170,
#  'omg': 607,
#  'thankful': 844,
#  'positive': 652,
#  'thankful positive': 845,
#  'retweet': 700,
#  'agree': 26,
#  'friday': 322,
#  'smile': 772,
#  'around': 54,
#  'via': 908,
#  'make': 527,
#  'people': 626,
#  'know': 457,
#  'oil': 602,
#  'made': 526,
#  'euro2016': 253,
#  'goal': 348,
#  'gave': 335,
#  'away': 62,
#  'free': 319,
#  'hit': 413,
#  'sad': 712,
#  'little': 497,
#  'cat': 143,
#  'funny': 330,
#  'laugh': 465,
#  'product': 664,
#  'man': 530,
#  'wine': 953,
#  'who': 949,
#  'weekend': 939,
#  'open': 610,
#  'drink': 234,
#  'say': 719,
#  'tgif': 842,
#  'beautiful': 76,
#  'sign': 753,
#  'medium': 537,
#  'ðð': 993,
#  'sunday': 812,
#  'great': 367,
#  'service': 735,
#  '50': 12,
#  'went': 943,
#  'good': 355,
#  'night': 594,
#  'action': 16,
#  'mean': 536,
#  'lost': 512,
#  'family': 272,
#  'forever': 312,
#  'never': 587,
#  'vote': 919,
#  'excited': 262,
#  'look': 506,
#  'different': 219,
#  'rip': 704,
#  'tonight': 867,
#  'hard': 384,
#  'monday': 558,
#  'due': 235,
#  'need': 582,
#  'something': 777,
#  'like': 491,
#  'bull': 122,
#  'dominate': 228,
#  'direct': 221,
#  'whatever': 945,
#  'want': 927,
#  'bull dominate': 124,
#  'dominate bull': 229,
#  'bull direct': 123,
#  'direct whatever': 222,
#  'whatever want': 946,
#  'morning': 562,
#  'one': 608,
#  'word': 961,
#  'tell': 840,
#  'oh': 601,
#  'hour': 420,
#  'line': 493,
#  'working': 965,
#  'close': 162,
#  'sunshine': 815,
#  'finally': 290,
#  'book': 108,
#  'youve': 990,
#  'life': 486,
#  'social': 775,
#  'share': 739,
#  'lovely': 516,
#  'amazing': 39,
#  'i_am': 428,
#  'affirmation': 22,
#  'i_am positive': 429,
#  'positive affirmation': 653,
#  'go': 347,
#  'wrong': 972,
#  'feeling': 285,
#  'blue': 102,
#  'best': 85,
#  'pa': 617,
#  'getting': 340,
#  'ready': 686,
#  'prayfororlando': 659,
#  'got': 363,
#  'job': 444,
#  'ððððð': 997,
#  'first': 297,
#  'let': 478,
#  'begin': 82,
#  'thank': 843,
#  'super': 816,
#  'âï': 992,
#  'wedding': 936,
#  'playing': 640,
#  'peace': 625,
#  'mr': 570,
#  'video': 913,
#  'world': 967,
#  'time': 861,
#  'fashion': 276,
#  'style': 807,
#  'selfie': 731,
#  'work': 962,
#  'conference': 175,
#  'right': 702,
#  'mindset': 548,
#  'lead': 470,
#  'cultureofdevelopment': 190,
#  'organization': 612,
#  'work conference': 963,
#  'conference right': 176,
#  'right mindset': 703,
#  'mindset lead': 549,
#  'lead cultureofdevelopment': 471,
#  'cultureofdevelopment organization': 191,
#  'organization work': 613,
#  'work mindset': 964,
#  'last': 460,
#  'shot': 748,
#  'voice': 918,
#  'dance': 200,
#  'student': 804,
#  'really': 689,
#  'hu': 424,
#  'wife': 951,
#  'miss': 552,
#  'show': 749,
#  'name': 576,
#  'shes': 740,
#  'everything': 261,
#  'celebrate': 145,
#  'every': 258,
#  'sure': 819,
#  'white': 948,
#  'running': 711,
#  'loving': 519,
#  'travel': 874,
#  'yeah': 977,
#  'good morning': 357,
#  'new': 588,
#  'arrived': 56,
#  'exciting': 263,
#  'much': 571,
#  'stuff': 805,
#  'happening': 381,
#  'florida': 302,
#  'shooting': 744,
#  'two': 889,
#  'old': 605,
#  'point': 643,
#  'test': 841,
#  'proud': 665,
#  'udtapunjab': 890,
#  'finger': 295,
#  'hey': 407,
#  'race': 672,
#  'might': 544,
#  'sometimes': 778,
#  'strong': 803,
#  'hâ': 427,
#  'men': 542,
#  'gun': 372,
#  'control': 179,
#  'wont': 960,
#  'stop': 800,
#  'black': 95,
#  'power': 655,
#  'mind': 547,
#  'heal': 394,
#  'body': 105,
#  'altwaystoheal': 36,
#  'healthy': 398,
#  'altwaystoheal healthy': 37,
#  'week': 938,
#  'far': 275,
#  'place': 637,
#  'member': 540,
#  'music': 572,
#  'watching': 932,
#  'episode': 251,
#  'nice': 592,
#  'long': 505,
#  'snapchat': 774,
#  '15': 3,
#  'thing': 851,
#  'yes': 980,
#  'back': 67,
#  'history': 412,
#  'daughter': 203,
#  'son': 779,
#  'enjoy': 246,
#  'memory': 541,
#  'way': 934,
#  'done': 230,
#  'course': 187,
#  'ill': 432,
#  'always': 38,
#  'hope': 417,
#  'gonna': 354,
#  'happen': 379,
#  'soon': 781,
#  'couple': 186,
#  'sex': 737,
#  'gbp': 337,
#  'shop': 745,
#  'cool': 180,
#  'home': 415,
#  'fun': 329,
#  'get shop': 339,
#  'shop cool': 746,
#  'cool home': 181,
#  'home fun': 416,
#  'truly': 878,
#  'sick': 751,
#  'ppl': 656,
#  'trump': 879,
#  'obama': 598,
#  'boy': 111,
#  'talk': 827,
#  'change': 147,
#  'fresh': 321,
#  'high': 408,
#  'going': 350,
#  'la': 458,
#  'friend': 324,
#  'still': 798,
#  'head': 392,
#  'fact': 270,
#  'gone': 353,
#  'wait': 920,
#  'sta': 789,
#  'ðððððð': 998,
#  'cant wait': 138,
#  'relax': 694,
#  'woman': 957,
#  'doesnt': 226,
#  'racism': 676,
#  'apple': 52,
#  'song': 780,
#  'vine': 915,
#  'brexit': 115,
#  '100': 1,
#  'health': 397,
#  'followme': 308,
#  'instagood': 436,
#  'alone': 32,
#  'lonely': 504,
#  'ride': 701,
#  'gym': 374,
#  'polar': 644,
#  'bear': 73,
#  'climb': 158,
#  'racing': 673,
#  'angry': 42,
#  'living': 499,
#  'cold': 165,
#  'looking': 508,
#  'polar bear': 645,
#  'bear climb': 74,
#  'climb racing': 159,
#  'racing angry': 674,
#  'angry polar': 43,
#  'racing polar': 675,
#  'bear living': 75,
#  'living cold': 500,
#  'cold place': 166,
#  'muslim': 573,
#  'waiting': 922,
#  'football': 311,
#  'usa': 898,
#  'writing': 971,
#  'tear': 836,
#  'bird': 92,
#  'pretty': 662,
#  'female': 286,
#  'killed': 453,
#  'ok': 604,
#  'animal': 44,
#  'arent': 53,
#  'republican': 696,
#  'find': 292,
#  'guy': 373,
#  'update': 894,
#  'photooftheday': 632,
#  'anyone': 49,
#  'date': 202,
#  'even': 254,
#  'put': 668,
#  'impoant': 433,
#  'matter': 533,
#  'sho': 742,
#  'actor': 17,
#  'human': 425,
#  'thought': 856,
#  'prayer': 658,
#  'gay': 336,
#  'album': 29,
#  'community': 171,
#  'target': 829,
#  'ive': 443,
#  'bad': 68,
#  'worst': 968,
#  'ever': 257,
#  'blessed': 97,
#  'disney': 224,
#  'found': 316,
#  'id': 430,
#  'hair': 376,
#  'lt3': 521,
#  'listen': 495,
#  'best friend': 86,
#  'freedom': 320,
#  'present': 660,
#  'past': 622,
#  'yall': 975,
#  'aint': 28,
#  'gorilla': 361,
#  'racist': 677,
#  'broken': 117,
#  'watch': 931,
#  'slut': 769,
#  'hand': 378,
#  'game': 332,
#  'everyone': 260,
#  'goodmorning': 358,
#  'hea': 390,
#  'saturday': 716,
#  'afternoon': 23,
#  'meet': 538,
#  'aww': 64,
#  'bing': 90,
#  'bong': 106,
#  'aww yeah': 65,
#  'yeah good': 978,
#  'good bing': 356,
#  'bing bong': 91,
#  'bong bing': 107,
#  'month': 560,
#  'seeing': 727,
#  'live': 498,
#  'summer': 809,
#  'hear': 400,
#  'god': 349,
#  'coming': 169,
#  'another': 46,
#  'happened': 380,
#  'together': 865,
#  'depressed': 211,
#  'post': 654,
#  'check': 149,
#  'saw': 718,
#  'said': 714,
#  'last night': 461,
#  'already': 34,
#  'question': 670,
#  'news': 589,
#  'victim': 912,
#  'happiness': 383,
#  'state': 795,
#  'quote': 671,
#  'safe': 713,
#  'healing': 395,
#  'healthy healing': 399,
#  'thursday': 858,
#  '10': 0,
#  'forward': 315,
#  'looking forward': 509,
#  'reached': 683,
#  'follower': 307,
#  'teen': 839,
#  'country': 185,
#  'bring': 116,
#  'come': 168,
#  'eat': 238,
#  'lunch': 524,
#  'lawofattraction': 468,
#  'success': 808,
#  'joy': 447,
#  'libtard': 482,
#  'sjw': 765,
#  'liberal': 480,
#  'politics': 648,
#  'might libtard': 546,
#  'libtard libtard': 483,
#  'libtard sjw': 484,
#  'sjw liberal': 766,
#  'liberal politics': 481,
#  'attack': 59,
#  '3d': 10,
#  'empty': 242,
#  'city': 155,
#  'side': 752,
#  'attack bull': 60,
#  'bull game': 125,
#  'game 3d': 333,
#  '3d really': 11,
#  'really think': 690,
#  'think head': 853,
#  'head empty': 393,
#  'empty around': 243,
#  'around city': 55,
#  'keep': 450,
#  'eye': 267,
#  'president': 661,
#  'money': 559,
#  'cannot': 135,
#  'could': 182,
#  'cute': 193,
#  'sun': 811,
#  'cute summer': 195,
#  'seems': 728,
#  'moment': 557,
#  'lucky': 523,
#  'isnt': 441,
#  'complete': 172,
#  'america': 40,
#  'dad': 196,
#  'give': 344,
#  'customer': 192,
#  'beer': 81,
#  'food': 310,
#  'day': 204,
#  'left': 477,
#  'countdown': 184,
#  'club': 163,
#  'there': 849,
#  'reason': 691,
#  'stay': 796,
#  'else': 240,
#  'app': 51,
#  'end': 244,
#  'yay': 976,
#  'rest': 698,
#  'thats': 848,
#  'try': 881,
#  'help': 404,
#  'baby': 66,
#  'bought': 110,
#  'finding': 294,
#  'ticket': 859,
#  'minute': 551,
#  'lose': 510,
#  'second': 724,
#  'tech': 838,
#  'would': 969,
#  'able': 13,
#  'suppo': 817,
#  'event': 256,
#  'puppy': 666,
#  'till': 860,
#  'yesterday': 981,
#  'mad': 525,
#  'dog': 227,
#  'wonderful': 959,
#  'loved': 515,
#  'youre': 987,
#  'play': 639,
#  'kind': 454,
#  'sunny': 813,
#  'others': 616,
#  'pic': 634,
#  'love': 514,
#  'true': 877,
#  'pussy': 667,
#  '30': 9,
#  'many': 531,
#  'nothing': 595,
#  'bitch': 94,
#  'care': 142,
#  'fathersday': 280,
#  'wishing': 955,
#  'client': 157,
#  'choose': 154,
#  'lifestyle': 487,
#  'self': 730,
#  'half': 377,
#  'idea': 431,
#  'understand': 892,
#  'maybe': 535,
#  'violence': 916,
#  'fucking': 327,
#  '2nd': 8,
#  'leaving': 476,
#  'heard': 401,
#  'trying': 882,
#  'mood': 561,
#  'flight': 301,
#  'reading': 685,
#  'ur': 895,
#  'emotion': 241,
#  'wish': 954,
#  'real': 687,
#  'na': 575,
#  'hot': 419,
#  'nasty': 577,
#  'naughty': 580,
#  'sexy': 738,
#  'horny': 418,
#  'shy': 750,
#  'porn': 651,
#  'nude': 596,
#  'kinky': 456,
#  'xxx': 974,
#  'instead': 439,
#  'folk': 305,
#  'launch': 466,
#  'enjoying': 247,
#  'vegan': 907,
#  'ask': 58,
#  '2016': 6,
#  'better': 87,
#  'please': 641,
#  'shoe': 743,
#  'poor': 649,
#  'kill': 452,
#  'used': 900,
#  'nbafinals': 581,
#  'grateful': 365,
#  'grateful affirmation': 366,
#  'brother': 118,
#  'wait see': 921,
#  'light': 488,
#  'training': 873,
#  'lover': 517,
#  'fuck': 326,
#  'guess': 371,
#  'latest': 464,
#  'bless': 96,
#  'final': 289,
#  'green': 368,
#  'class': 156,
#  'team': 835,
#  'hatred': 387,
#  'simulator': 760,
#  'adapt': 19,
#  'environment': 249,
#  'gorilla simulator': 362,
#  'simulator need': 761,
#  'need adapt': 583,
#  'adapt environment': 20,
#  'environment need': 250,
#  'need tear': 584,
#  'tear city': 837,
#  'leadership': 472,
#  'as': 57,
#  'pathetic': 623,
#  'movie': 568,
#  'htâ': 423,
#  'breakfast': 114,
#  'rock': 706,
#  'pop': 650,
#  'june': 449,
#  'lol': 502,
#  'meeting': 539,
#  'problem': 663,
#  'chill': 152,
#  'tweet': 886,
#  'sister': 764,
#  'death': 207,
#  'twitter': 888,
#  'mother': 563,
#  'healing altwaystoheal': 396,
#  'soul': 783,
#  'buffalo': 119,
#  'damn': 199,
#  'without': 956,
#  'young': 986,
#  'nigga': 593,
#  'shit': 741,
#  'sunset': 814,
#  'fitness': 299,
#  'well': 941,
#  'dream': 233,
#  'move': 567,
#  'follow': 306,
#  'since': 762,
#  'staed': 790,
#  'turn': 884,
#  'american': 41,
#  'lady': 459,
#  'visit': 917,
#  'father dad': 278,
#  'awesome': 63,
#  'theyre': 850,
#  'face': 268,
#  'taking': 826,
#  'dinner': 220,
#  'euro': 252,
#  'france': 318,
#  'bit': 93,
#  'law': 467,
#  'inspiration': 435,
#  'sale': 715,
#  'shopping': 747,
#  'cheer': 150,
#  'house': 421,
#  'buy': 129,
#  'sweet': 822,
#  'tragedy': 871,
#  'busy': 128,
#  'feel': 283,
#  'havent': 388,
#  'film': 288,
#  'photo': 630,
#  'perfect': 627,
#  'missing': 553,
#  'season': 723,
#  'booked': 109,
#  'beach': 72,
#  'park': 621,
#  'story': 801,
#  'anxiety': 47,
#  'wow': 970,
#  'child': 151,
#  'thinking': 854,
#  'wet': 944,
#  'flower': 303,
#  'special': 787,
#  'friendship': 325,
#  'fantastic': 274,
#  'room': 707,
#  'group': 369,
#  'uk': 891,
#  'holiday': 414,
#  'issue': 442,
#  'oitnb': 603,
#  'stas': 794,
#  'making': 529,
#  'father father': 279,
#  'view': 914,
#  'nyc': 597,
#  'truth': 880,
#  '20': 5,
#  'send': 732,
#  'london': 503,
#  'stomping': 799,
#  'feel like': 284,
#  'like stomping': 492,
#  'police': 646,
#  'choice': 153,
#  'fall': 271,
#  'behind': 83,
#  'actually': 18,
#  'look like': 507,
#  'vacation': 904,
#  'remember': 695,
#  'become': 79,
#  'reality': 688,
#  'tv': 885,
#  'star': 793,
#  'allahsoil': 30,
#  'fridayfeeling': 323,
#  'easy': 237,
#  'tired': 863,
#  'nervous': 586,
#  'didnt': 217,
#  'parent': 620,
#  'httâ': 422,
#  'everyday': 259,
#  'dear': 206,
#  'despite': 215,
#  'tragic': 872,
#  'color': 167,
#  'finished': 296,
#  'walk': 924,
#  'gift': 341,
#  'future': 331,
#  'save': 717,
#  'husband': 426,
#  'chase': 148,
#  'boyfriend': 112,
#  'smiling': 773,
#  'yet': 982,
#  'dont know': 232,
#  'saying': 720,
#  'read': 684,
#  'yoga': 984,
#  'also': 35,
#  'garden': 334,
#  'conce': 174,
#  'here': 405,
#  'mine': 550,
#  'gorgeous': 360,
#  'sky': 767,
#  'rather': 680,
#  'design': 214,
#  'set': 736,
#  'top': 868,
#  'smh': 771,
#  'youtube': 989,
#  'moving': 569,
#  'yr': 991,
#  'ago': 25,
#  'online': 609,
#  'tbt': 833,
#  'tbt cute': 834,
#  'cute beautiful': 194,
#  'beautiful followme': 77,
#  'water': 933,
#  'adventure': 21,
#  'series': 733,
#  'tuesday': 883,
#  'believe': 84,
#  'england': 245,
#  'daily': 198,
#  'plan': 638,
#  'ahead': 27,
#  'india': 434,
#  'spos': 788,
#  'join': 445,
#  'full': 328,
#  'sleep': 768,
#  'congrats': 177,
#  'ó¾': 999,
#  'education': 239,
#  'die': 218,
#  'le': 469,
#  'lot': 513,
#  'source': 785,
#  'despite fact': 216,
#  'youre strong': 988,
#  'cry': 189,
#  'wanted': 929,
#  'street': 802,
#  'hell': 402,
#  'happier': 382,
#  'least': 474,
#  'nature': 579,
#  'card': 141,
#  'loveâ': 518,
#  'hill': 409,
#  'reach': 681,
#  'task': 831,
#  'survive': 821,
#  'bull hill': 126,
#  'hill climb': 410,
#  'climb reach': 160,
#  'reach target': 682,
#  'target complete': 830,
#  'complete task': 173,
#  'task survive': 832,
#  'hillary': 411,
#  'phone': 629,
#  'gotta': 364,
#  'fly': 304,
#  'poetry': 642,
#  'favorite': 281,
#  'person': 628,
#  'simulation': 757,
#  'vicinity': 910,
#  'buffalo simulation': 120,
#  'simulation buffalo': 758,
#  'buffalo take': 121,
#  'take vicinity': 825,
#  'vicinity home': 911,
#  'hardcore': 385,
#  'order': 611,
#  'needed': 585,
#  'dj': 225,
#  'bag': 69,
#  'wednesday': 937,
#  'road': 705,
#  'break': 113,
#  'came': 133,
#  'dark': 201,
#  'win': 952,
#  'gop': 359,
#  'list': 494,
#  'rooster': 708,
#  'vast': 905,
#  'expanse': 264,
#  'mountain': 565,
#  'rooster simulation': 709,
#  'simulation want': 759,
#  'want climb': 928,
#  'climb vast': 161,
#  'vast expanse': 906,
#  'expanse mountain': 265,
#  'mountain reached': 566,
#  'using': 903,
#  'rain': 678,
#  'political': 647,
#  'evening': 255,
#  'cake': 130,
#  'vibe': 909,
#  'business': 127,
#  'red': 692,
#  'enough': 248,
#  'lgbt': 479,
#  'single': 763,
#  'pain': 619,
#  'instagram': 438,
#  'makeup': 528,
#  'stand': 792,
#  'small': 770,
#  'luck': 522,
#  'speak': 786,
#  'staing': 791,
#  'bed': 80,
#  'simple': 756,
#  'car': 140,
#  'next week': 591,
#  'he': 389,
#  'someone': 776,
#  'age': 24,
#  'mass': 532,
#  'haha': 375,
#  'secret': 725,
#  'loss': 511,
#  'picture': 636,
#  'anniversary': 45,
#  'official': 599,
#  'blogger': 100,
#  'bday': 71,
#  'ramadan': 679,
#  'suppoers': 818,
#  'islam': 440,
#  'forget': 314,
#  'bc': 70,
#  'glad': 346,
#  'delete': 208,
#  'useful': 901,
#  'deletetweets': 210,
#  'finally found': 291,
#  'found way': 317,
#  'way delete': 935,
#  'delete old': 209,
#  'old tweet': 606,
#  'tweet might': 887,
#  'might find': 545,
#  'find useful': 293,
#  'useful well': 902,
#  'well deletetweets': 942,
#  'trip': 876,
#  'national': 578,
#  'crazy': 188,
#  'depression': 212,
#  'experience': 266,
#  'camp': 134,
#  'fear': 282,
#  'lighttherapy': 489,
#  'lighttherapy help': 490,
#  'depression altwaystoheal': 213,
#  'along': 33,
#  'anything': 50,
#  'cantwait': 139,
#  'couldnt': 183,
#  'whats': 947,
#  'war': 930,
#  'cant believe': 137,
#  'dead': 205,
#  'respect': 697,
#  'walking': 925,
#  'disappointed': 223,
#  'sea': 722,
#  'hello': 403,
#  'must': 574,
#  'officially': 600,
#  'whole': 950,
#  'sorry': 782,
#  'message': 543,
#  'learn': 473,
#  'award': 61,
#  'celebration': 146,
#  'late': 462,
#  'treat': 875,
#  'king': 455,
#  'though': 855,
#  'joke': 446,
#  'content': 178,
#  'picoftheday': 635,
#  'low': 520,
#  'festival': 287,
#  'early': 236,
#  'giving': 345,
#  'local': 501,
#  'flag': 300,
#  'toptags': 869,
#  'followâ': 309,
#  'instagood photooftheday': 437,
#  'photooftheday toptags': 633,
#  'toptags tbt': 870,
#  'queen': 669,
#  'step': 797,
#  'beauty': 78,
#  'tip': 862,
#  'wtf': 973,
#  'facebook': 269,
#  'account': 14,
#  'act': 15,
#  'seriously': 734,
#  'wanna': 926,
#  '1st': 4,
#  '2017': 7,
#  'yo': 983,
#  'coffee': 164,
#  'almost': 31,
#  'photography': 631,
#  'anymore': 48,
#  'gt': 370,
#  'york': 985,
#  'surprise': 820,
#  'pray': 657,
#  'july': 448,
#  'blur': 103,
#  'girl cute': 343,
#  'summer blur': 810,
#  'blur sun': 104,
#  'heabroken': 391,
#  'blonde': 101,
#  '12': 2,
#  'seen': 729,
#  'listen retweet': 496,
#  'university': 893,
#  'thankyou': 847,
#  'stupid': 806,
#  'result': 699,
#  'relationship': 693,
#  'page': 618,
#  'wake': 923,
#  'wonder': 958,
#  'later': 463,
#  'lie': 485,
#  'called': 132,
#  'hero': 406,
#  'fit': 298,
#  'three': 857,
#  'sound': 784,
#  'workout': 966}

# %%
for k, v in bow.vocabulary_.items():
    print(k)
    print(bin(v))
# Out:
# father
# 0b100010101
# kid
# 0b111000011
# run
# 0b1011000110
# thanks
# 0b1101001110
# cant
# 0b10001000
# use
# 0b1110000011
# cause
# 0b10010000
# dont
# 0b11100111
# bihday
# 0b1011001
# model
# 0b1000101010
# take
# 0b1100110111
# urð
# 0b1110000000
# ðððð
# 0b1111100011
# ððð
# 0b1111100010
# model take
# 0b1000101011
# take urð
# 0b1100111000
# urð ðððð
# 0b1110000001
# ðððð ððð
# 0b1111100100
# motivation
# 0b1000110100
# fan
# 0b100010001
# big
# 0b1011000
# talking
# 0b1100111100
# leave
# 0b111011011
# pay
# 0b1001110000
# get
# 0b101010010
# tomorrow
# 0b1101100010
# next
# 0b1001001110
# school
# 0b1011010001
# year
# 0b1111010011
# think
# 0b1101010100
# hate
# 0b110000010
# girl
# 0b101010110
# welcome
# 0b1110101100
# mom
# 0b1000101100
# may
# 0b1000010110
# blog
# 0b1100010
# silver
# 0b1011110010
# gold
# 0b101011111
# forex
# relationship
# 0b1010110101
# page
# 0b1001101010
# wake
# 0b1110011011
# wonder
# 0b1110111110
# later
# 0b111001111
# lie
# 0b111100101
# called
# 0b10000100
# hero
# 0b110010110
# fit
# 0b100101010
# three
# 0b1101011001
# sound
# 0b1100010000
# workout
# 0b1111000110

# %%
train['sentiment'] = train['tweet'].apply(lambda x: TextBlob(x).sentiment[0] )
train[['tweet','sentiment']].head()
# Out:
#                                                tweet  sentiment
# 0  father dysfunctional selfish drag kid dysfunct...       -0.3
# 1  thanks lyft credit cant use cause dont offer w...        0.2
# 2                                     bihday majesty        0.0
# 3                            model take urð ðððð ððð        0.0
# 4                      factsguide society motivation        0.0

# %%
#before run download:
# http://nlp.stanford.edu/data/glove.6B.zip

from gensim.scripts.glove2word2vec import glove2word2vec
glove_input_file = 'glove.6B.100d.txt'
word2vec_output_file = 'glove.6B.100d.txt.word2vec'
glove2word2vec(glove_input_file, word2vec_output_file)
# Out:
# (400000, 100)

# %%
from gensim.models import KeyedVectors # load the Stanford GloVe model
filename = 'glove.6B.100d.txt.word2vec'
model = KeyedVectors.load_word2vec_format(filename, binary=False)

# %%
model['go']
# Out:
# array([-0.078894,  0.4616  ,  0.57779 , -0.71637 , -0.13121 ,  0.4186  ,
#        -0.29156 ,  0.52006 ,  0.089986, -0.35062 ,  0.51755 ,  0.51998 ,
#         0.15218 ,  0.41485 , -0.12377 , -0.37222 ,  0.0273  ,  0.75673 ,
#        -0.8739  ,  0.58935 ,  0.46662 ,  0.62918 ,  0.092603, -0.012868,
#        -0.015169,  0.25567 , -0.43025 , -0.77668 ,  0.71449 , -0.3834  ,
#        -0.69638 ,  0.23522 ,  0.11396 ,  0.02778 ,  0.071357,  0.87409 ,
#        -0.1281  ,  0.063576,  0.067867, -0.50181 , -0.28523 , -0.072536,
#        -0.50738 , -0.6914  , -0.53579 , -0.11361 , -0.38234 , -0.12414 ,
#         0.011214, -1.1622  ,  0.037057, -0.18495 ,  0.01416 ,  0.87193 ,
#        -0.097309, -2.3565  , -0.14554 ,  0.28275 ,  2.0053  ,  0.23439 ,
#        -0.38298 ,  0.69539 , -0.44916 , -0.094157,  0.90527 ,  0.65764 ,
#         0.27628 ,  0.30688 , -0.57781 , -0.22987 , -0.083043, -0.57236 ,
#        -0.299   , -0.81112 ,  0.039752, -0.05681 , -0.48879 , -0.18091 ,
#        -0.28152 , -0.20559 ,  0.4932  , -0.033999, -0.53139 , -0.28297 ,
#        -1.4475  , -0.18685 ,  0.091177,  0.11454 , -0.28168 , -0.33565 ,
#        -0.31663 , -0.1089  ,  0.10111 , -0.23737 , -0.64955 , -0.268   ,
#         0.35096 ,  0.26352 ,  0.59397 ,  0.26741 ], dtype=float32)

# %%
model['away']
# Out:
# array([-0.10379 , -0.014792,  0.59933 , -0.51316 , -0.036463,  0.6588  ,
#        -0.57906 ,  0.17819 ,  0.23663 , -0.21384 ,  0.55339 ,  0.53597 ,
#         0.041444,  0.16095 ,  0.017093, -0.37242 ,  0.017974,  0.39268 ,
